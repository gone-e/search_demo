# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style, rc, font_manager
# %matplotlib inline
# style 설정
# https://fredriccliver.medium.com/cant-not-see-axis-label-of-jupyter-notebook-in-the-dark-theme-vscode-df31a3ee121
# print(plt.style.available)
# style.use('dark_background')
# style.use('seaborn-darkgrid')
style.use('ggplot')
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = True 
# font 설정
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
import random
import ast
import json
import numpy as np
from scipy.stats import skew

# %%
# read data
# df = pd.read_csv("./card.click.ranking.base.1m.rs.1K.v2.csv")
# df = pd.read_csv("./card.click.ranking.base.1m.rs.1K.v2.sr.csv")
df = pd.read_csv("./card.click.ranking.base.1d.rs.1K.v2.sr.csv")

def to_json(x):
    return ast.literal_eval(x)
def get_length(x):
    return len(x)

df["rank2docinfo"] = df["rank2docinfo"].apply(to_json)

print(len(df))
df.head()
# Out:
# 61
#   search_keyword   qc   cc        ctr  uqc  ucc       uctr  docCnt  \
# 0             홈쿡   56   19  33.928571   30   11  36.666667    1093
# 1             액자  151   85  56.291391   48   24  50.000000    1919
# 2            벽시계  158  117  74.050633   33   23  69.696970     245
# 3            발매트  249  135  54.216867   89   35  39.325843     855
# 4            봄캠핑  145   82  56.551724   39   21  53.846154     171
#
#                                         rank2docinfo
# 0  {'1': {'id': '10455624', 'qc': 53, 'cc': 2, 'c...
# 1  {'1': {'id': '15642317', 'qc': 64, 'cc': 1, 'c...
# 2  {'1': {'id': '5884686', 'qc': 40, 'cc': 1, 'ct...
# 3  {'1': {'id': '15460503', 'qc': 131, 'cc': 4, '...
# 4  {'1': {'id': '16394241', 'qc': 76, 'cc': 2, 'c...

# %%
for idx, row in df.iterrows():
    # if idx == 1: break
    cnt = 0
    for rank, docinfo in row["rank2docinfo"].items():
        print(row["uqc"], rank, docinfo["uqc"])
        # if row["uqc"] == docinfo["uqc"]:
            # print(row["search_keyword"], rank, row["qc"], row["cc"], row["uqc"], row["ucc"], docinfo["qc"], docinfo["cc"], docinfo["uqc"], docinfo["ucc"])
        if docinfo["qc"] == -1:
            # print(rank, docinfo)
            print(docinfo["id"])
            cnt += 1
    if cnt > 1:
        print(cnt)
# Out:
# 30 1 37
# 30 2 37
# 30 3 37
# 30 4 14
# 30 5 14
# 30 6 23
# 30 7 19
# 30 8 19
# 30 9 8
# 30 10 10
# 30 11 8
# 30 12 16
# 30 13 8
# 30 14 14
# 30 15 11
# 30 16 8
# 30 17 13
# 30 18 11
# 30 19 11
# 30 20 11
# 30 21 8
# 30 22 33
# 30 23 11
# 30 24 11
# 30 25 10
# 30 26 11
# 30 27 11
# 30 28 9
# 30 29 9
# 30 30 32
# 30 31 9
# 30 32 9
# 30 33 9
# 30 34 30
# 30 35 9
# 30 36 9
# 30 37 9
# 30 38 19
# 30 39 9
# 30 40 9
# 30 41 8
# 30 42 9
# 30 43 8
# 30 44 8
# 30 45 7
# 30 46 7
# 30 47 7
# 30 48 7
# 30 49 7
# 30 50 15
# 30 51 8
# 30 52 7
# 30 53 7
# 30 54 7
# 30 55 7
# 30 56 13
# 30 57 7
# 30 58 6
# 30 59 7
# 30 60 5
# 30 61 7
# 30 62 6
# 30 63 12
# 30 64 7
# 30 65 7
# 30 66 7
# 30 67 10
# 30 68 9
# 30 69 7
# 30 70 9
# 30 71 7
# 30 72 9
# 30 73 6
# 30 74 6
# 30 75 6
# 30 76 6
# 30 77 9
# 30 78 6
# 30 79 6
# 30 80 6
# 30 81 4
# 30 82 6
# 30 83 6
# 30 84 6
# 30 85 6
# 30 86 9
# 30 87 6
# 30 88 6
# 30 89 9
# 30 90 6
# 30 91 6
# 30 92 6
# 30 93 6
# 30 94 6
# 30 95 6
# 30 96 6
# 30 97 6
# 30 98 6
# ...
